# %% [markdown]
# In this example we are going to scrape [Iowa's Professional Licensing](https://ia-plb.my.site.com/LicenseSearchPage) website for appraisal management companies. (Why? Who knows, why *not?*)
#
# Traditionally Python programmers use [BeautifulSoup](https://beautiful-soup-4.readthedocs.io/en/latest/) to scrape content from the interent. Instead of being *traditional*, we're going to use [Playwright](https://playwright.dev/python/), a **browser automation tool**! This means you actually control the browser! Filling out forms, clicking buttons, downloading documents... it's magic!!!✨✨✨
#
# # Iowa Appraisal Management Companies
#
# - Dropdowns
# - Clicking 'Next page' button again and again
# - Combining dataframes

# %% [markdown]
# ## Installation
#
# We need to install a few tools first! Remove the `#` and run the cell to install the Python packages and browsers that we'll need for our scraping adventure.

# %%
# %pip install --quiet lxml html5lib beautifulsoup4 pandas
# %pip install --quiet playwright
# !playwright install chromium firefox

# %% [markdown]
# And we'll set it up so Playwright will be sure to work on Windows.

# %%
# Detect if we're running in Google Colab
import os
IN_COLAB = 'COLAB_GPU' in os.environ or 'COLAB_RELEASE_TAG' in os.environ

import platform
import asyncio
import nest_asyncio

if platform.system() == "Windows":
    asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

try:
    asyncio.get_running_loop()
    nest_asyncio.apply()
except RuntimeError:
    pass

# %% [markdown]
# ## Opening up the browser and visiting our destination

# %%
from playwright.async_api import async_playwright

# "Hey, open up a browser"
playwright = await async_playwright().start()

# Colab can't open a visible browser, so we run headless there
if IN_COLAB:
    use_headless = True
else:
    use_headless = False

browser = await playwright.chromium.launch(headless=use_headless)

# Create a new browser window
page = await browser.new_page()

# %%
await page.goto("https://ia-plb.my.site.com/LicenseSearchPage")
# Out:
# <Response url='https://ia-plb.my.site.com/LicenseSearchPage' request=<Request url='https://ia-plb.my.site.com/LicenseSearchPage' method='GET'>>

# %%
from IPython.display import Image
screenshot = await page.screenshot()
Image(screenshot)

# %% [markdown]
# ## Selecting an option from a dropdown
#
# You always start with `await page.locator("select").select_option("whatever option you want")`. You'll probably get an error because there are multiple dropdowns on the page, but Playwright doesn't know which one you want to use! Just read the error and figure out the right one.

# %%
# await page.locator("select").select_option("Appraisal Management Company")
await page.get_by_label("Licensing Board:").select_option("Appraisal Management Company")
# Out:
# ['Appraisal Management Company']

# %%
# await page.get_by_text("Search").click()
await page.locator("input[name=\"j_id0\\:j_id1\\:j_id14\\:j_id73\"]").click()

# %% [markdown]
# ## Grab the tables from the page
#
# [Pandas](https://pandas.pydata.org/) is the Python equivalent to Excel, and it's great at dealing with tabular data! Often the data on a web page that looks like a spreadsheet can be read with `pd.read_html`.
#
# You use `await page.content()` to save the contents of the page, then feed it to `read_html` to find the tables. `len(tables)` checks the number of tables you have, then you manually poke around to see which one is the one you're interested in. `tables[0]` is the first one, `tables[1]` is the second one, and so on...

# %%
import pandas as pd
from io import StringIO

html = await page.content()
tables = pd.read_html(StringIO(html))
len(tables)
# Out:
# 1

# %%
tables[0]
# Out:
#       Number                                           Licensee  \
# 14                   Active                  L-Z
# 15                   Active                  A-K
# 16                   Lapsed                  A-K
# 17                   Lapsed                  A-K
# 18                   Lapsed                  L-Z
# 19                   Active                  L-Z
# 20                   Active                  A-K
# 21                   Lapsed                  L-Z
# 22                   Lapsed                  L-Z
# 23                  Expired                  A-K
# 24  Voluntarily Surrendered                  A-K

# %% [markdown]
# ## Clicking "next page" one
#
# Just like using a dropdown, select box or button, we'll use `page.get_by_text` to try to select the button.
#
# We add `timeout=5000` to wait 5 seconds before confirming it isn't there.

# %%
# page.get_by_text("Next Page").click()
await page.locator("a:has-text('Next Page')").click(timeout=5000)

# %% [markdown]
# ## Clicking "next page" until it disappears
#
# Eventually the "next page" link disappears, and Python starts *screaming*. We use `try/except` down below to say "don't worry little baby, it's okay, we'll just finish up if the button is gone."
#
# When we move this into something nice and repeated, **we need to be careful!** Sometimes the page will load before the table does, so we add a line that says "don't get *too overeager*, wait up to 10 seconds for the table to show up first."

# %%
# all of our data will end up going here
all_data = pd.DataFrame()

while True:
    # Wait up to 10 seconds for the table to load
    await page.wait_for_selector("table", timeout=10000)  

    # Get all of the tables on the page
    html = await page.content()
    tables = pd.read_html(StringIO(html))

    # Get the table (and edit if necessary)
    df = tables[0]

    # Add the tables on this page to the big list of stuff
    all_data = pd.concat([all_data, df], ignore_index = True)

    # Save after each page in case something breaks
    all_data.to_csv("output.csv", index=False)

    try:
        await page.locator("a:has-text('Next Page')").click(timeout=5000)
    except:
        break

# %%
all_data
# Out:
#       Number                                           Licensee  \
# 0      00094  if(!window.sfdcPage) { window.sfdcPage = new A...
# 1      00014                                   OrderProUSA, LLC
# 2      00054                              Pendo Management, LLC
# 3      00008                             Pro-Teck Services, Ltd
# 4      00064                             Property Interlink LLC
# 5      00117                             Property Interlink LLC
# 6      00084                                   PropertyRate LLC
# 7   AMC00150                       R3 Appraisal Management, LLC
# 8      00091                    Radian Settlement Services Inc.
# 9      00018                      Radian Valuation Services LLC
# 10     00109               Real Estate Appraisal Solutions, LLC
# 11     00009                Real Estate Valuation Partners, LLC
# 12  AMC00343                         Red Sky Risk Services, LLC
# 13     00002                                  Rocket Close, LLC
# 14     00102                       RPM Appraisal Services, Inc.
# 15     00105             RRR Appraisal Services Management Inc.
# 16     00037                       RRR Appraisal Services, Inc.
# 17     00074  Service 1st Valuation and Settlement Services,...
# 18     00092                                   Service 1st, LLC
# 19     00011               ServiceLink Valuation Solutions, LLC
# 20     00100                       SettlementOne Valuation, LLC
# 21  AMC00152                 Signature Valuation Management Inc
# 22     00042               SingleSource Property Solutions, LLC
# 23     00001                                    Solidifi US Inc
# 24     00019                 Southwest Financial Services, Ltd.
# 25        16  if(!window.sfdcPage) { window.sfdcPage = new A...
# 26        46                                   Springhouse, LLC
# 27        38                Stewart Valuation Intelligence, LLC
# 28        17                    Stewart Valuation Services, LLC
# 29       130                          Suntender Valuations, Inc
# 30       353                      Superstition Management, Inc.
# 31       125                      Superstition Management, Inc.
# 36  Appraisal Management Company Registration  Appraisal Management Company
# 37  Appraisal Management Company Registration  Appraisal Management Company
# 38  Appraisal Management Company Registration  Appraisal Management Company
# 39  Appraisal Management Company Registration  Appraisal Management Company
# 40  Appraisal Management Company Registration  Appraisal Management Company
# 41  Appraisal Management Company Registration  Appraisal Management Company
# 42  Appraisal Management Company Registration  Appraisal Management Company
# 43  Appraisal Management Company Registration  Appraisal Management Company
# 44  Appraisal Management Company Registration  Appraisal Management Company
# 45  Appraisal Management Company Registration  Appraisal Management Company
# 46  Appraisal Management Company Registration  Appraisal Management Company
# 47  Appraisal Management Company Registration  Appraisal Management Company
# 48  Appraisal Management Company Registration  Appraisal Management Company
# 49  Appraisal Management Company Registration  Appraisal Management Company
# 50  Appraisal Management Company Registration  Appraisal Management Company
# 51  Appraisal Management Company Registration  Appraisal Management Company
# 52  Appraisal Management Company Registration  Appraisal Management Company
# 53  Appraisal Management Company Registration  Appraisal Management Company
# 54  Appraisal Management Company Registration  Appraisal Management Company
# 55  Appraisal Management Company Registration  Appraisal Management Company
#
#              License Status ContactLastNameGroup
# 0                    Active                  A-K
# 1                   Expired                  A-K
# 2   Voluntarily Surrendered                  A-K
# 3                    Lapsed                  L-Z
# 4   Voluntarily Surrendered                  A-K
# 5                    Lapsed                  A-K
# 6                    Active                  A-K
# 7                    Active                  A-K
# 8                   Expired                  L-Z
# 9                    Active                  A-K
# 10                   Lapsed                  A-K
# 11                   Lapsed                  A-K
# 12      Federally Regulated                  L-Z
# 13                   Active                  L-Z
# 14                  Expired                  L-Z
# 15                   Lapsed                  A-K
# 16                   Active                  L-Z
# 17                  Expired                  L-Z
# 18                   Active                  L-Z
# 19                   Active                  L-Z
# 20                   Lapsed                  A-K
# 21                   Active                  A-K
# 22                   Active                  A-K
# 23                   Active                  L-Z
# 24                  Expired                  L-Z
# 25                  Expired                  A-K
# 26                   Active                  L-Z
# 27                   Active                  A-K
# 28                   Lapsed                  A-K
# 29                   Active                  L-Z
# 30                 Canceled                  L-Z
# 31                   Lapsed                  A-K
# 32                   Lapsed                  L-Z
# 33                  Expired                  A-K
# 34                   Active                  A-K
# 35                   Active                  L-Z
# 36  Voluntarily Surrendered                  A-K
# 37                   Active                  A-K
# 38                   Lapsed                  A-K
# 39                   Lapsed                  A-K
# 40                   Lapsed                  L-Z
# 41                  Expired                  L-Z
# 42                  Expired                  L-Z
# 43                  Expired                  A-K
# 44                   Lapsed                  A-K
# 45  Voluntarily Surrendered                  L-Z
# 46                  Expired                  L-Z
# 47                   Active                  A-K
# 48                  Expired                  A-K
# 49                   Active                  L-Z
# 50                   Lapsed                  A-K
# 51                   Lapsed                  A-K
# 52                   Lapsed                  A-K
# 53                   Active                  L-Z
# 54                  Expired                  A-K
# 55                   Active                  L-Z

# %% [markdown]
# ## Saving the results
#
# Now we'll save it to a CSV file! Easy peasy.

# %%
all_data.to_csv("output.csv", index=False)
